# %%
import os
from os.path import expanduser
import json

# %%
home = expanduser("~"); home
# Out:
# '/Users/ncheever'

# %%
path_to_bookmarks = "Library/Application Support/Google/Chrome/Default/Bookmarks"

# %%
big_path= os.path.join(home, path_to_bookmarks)

# %%
if os.path.isfile(big_path):
    with open(big_path) as data_file:    
        data = json.load(data_file)

# %%
data
# Out:
# {u'checksum': u'570fee208d3d1ac812a8df067895c260',
#  u'roots': {u'bookmark_bar': {u'children': [{u'children': [{u'children': [{u'children': [{u'date_added': u'13114201346955574',
#            u'id': u'149',
#            u'name': u'Getting Spark Data from AWS S3 using Boto and Pyspark | wrightturn',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://wrightturn.wordpress.com/2015/07/22/getting-spark-data-from-aws-s3-using-boto-and-pyspark/'}],
#          u'date_added': u'13114201384218703',
#          u'date_modified': u'13114212417686463',
#          u'id': u'151',
#          u'name': u'Snowflake',
#          u'sync_transaction_version': u'3',
#          u'type': u'folder'},
#         {u'children': [{u'date_added': u'13114212417686463',
#            u'id': u'152',
#            u'name': u'@joeharris76: Migrating from SQL Server to Redshift',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'http://blog.joeharris76.com/2013/09/migrating-from-sql-server-to-redshift.html'},
#           {u'date_added': u'13115770953173244',
#            u'id': u'165',
#            u'name': u'AWS_Well-Architected_Framework.pdf',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://d0.awsstatic.com/whitepapers/architecture/AWS_Well-Architected_Framework.pdf'},
#           {u'date_added': u'13115770960801295',
#            u'id': u'166',
#            u'name': u'Microsoft Word - DOCKER_AWS_Whitepaper_-_v_1.0.docx',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://d0.awsstatic.com/whitepapers/docker-on-aws.pdf'},
#           {u'date_added': u'13115770965785462',
#            u'id': u'167',
#            u'name': u'extend-your-it-infrastructure-with-amazon-vpc.pdf',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://d0.awsstatic.com/whitepapers/extend-your-it-infrastructure-with-amazon-vpc.pdf'},
#           {u'date_added': u'13115770971016597',
#            u'id': u'168',
#            u'name': u'AWS_Cloud_Best_Practices.pdf',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://d0.awsstatic.com/whitepapers/AWS_Cloud_Best_Practices.pdf'}],
#          u'date_added': u'13114212432248175',
#          u'date_modified': u'13115770980601830',
#          u'id': u'153',
#          u'name': u'AWS',
#          u'sync_transaction_version': u'3',
#          u'type': u'folder'},
#         {u'children': [{u'date_added': u'13115767144509254',
#            u'id': u'163',
#            u'name': u'Schema Documentation Tags - Data Policies and Procedures - Ancestry Confluence',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://confluence.mfsbe.com/display/DPP/Schema+Documentation+Tags'},
#           {u'date_added': u'13115771004430078',
#            u'id': u'171',
#            u'name': u'Apache Avro\u2122 1.8.0 Specification',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'http://avro.apache.org/docs/1.8.0/spec.html'},
#           {u'date_added': u'13120773907600575',
#            u'id': u'610',
#            u'name': u'schema.mfsbedev.com/subjects/',
#            u'sync_transaction_version': u'367',
#            u'type': u'url',
#            u'url': u'http://schema.mfsbedev.com/subjects/'}],
#          u'date_added': u'13115767165355001',
#          u'date_modified': u'13121218893409392',
#          u'id': u'164',
#          u'name': u'Avro',
#          u'sync_transaction_version': u'3',
#          u'type': u'folder'},
#         {u'children': [{u'date_added': u'13118435835332826',
#            u'id': u'566',
#            u'name': u'nifi-templates/templates at master \xb7 hortonworks-gallery/nifi-templates',
#            u'sync_transaction_version': u'28',
#            u'type': u'url',
#            u'url': u'https://github.com/hortonworks-gallery/nifi-templates/tree/master/templates'},
#           {u'date_added': u'13120244264320997',
#            u'id': u'574',
#            u'name': u'nifi-templates/HandleNifiReports.xml at master \xb7 hortonworks-gallery/nifi-templates',
#            u'sync_transaction_version': u'41',
#            u'type': u'url',
#            u'url': u'https://github.com/hortonworks-gallery/nifi-templates/blob/master/templates/HandleNifiReports.xml'},
#           {u'date_added': u'13117672532249380',
#            u'id': u'182',
#            u'name': u'Monitoring An S3 Bucket in Apache NiFi',
#            u'sync_transaction_version': u'328',
#            u'type': u'url',
#            u'url': u'https://adamlamar.github.io/'},
#           {u'date_added': u'13117839149723945',
#            u'id': u'555',
#            u'name': u'Database Ingest with NiFi - BatchIQ',
#            u'sync_transaction_version': u'329',
#            u'type': u'url',
#            u'url': u'http://www.batchiq.com/database-injest-with-nifi.html'}],
#          u'date_added': u'13118435858187317',
#          u'date_modified': u'13120354656847645',
#          u'id': u'567',
#          u'name': u'NIFI',
#          u'sync_transaction_version': u'29',
#          u'type': u'folder'},
#         {u'children': [{u'date_added': u'13120261137689849',
#            u'id': u'578',
#            u'name': u'Migration Details.xlsx',
#            u'sync_transaction_version': u'52',
#            u'type': u'url',
#            u'url': u'https://ancestryonline-my.sharepoint.com/personal/mlaird_ancestry_com/_layouts/15/WopiFrame2.aspx?sourcedoc=%7B152B6F1C-BD13-46BD-B3FF-44A5F27DD6CA%7D&file=Migration%20Details.xlsx&action=default'}],
#          u'date_added': u'13120261166333238',
#          u'date_modified': u'13120350588886280',
#          u'id': u'579',
#          u'name': u'Migration',
#          u'sync_transaction_version': u'53',
#          u'type': u'folder'},
#         {u'date_added': u'13115770980601830',
#          u'id': u'169',
#          u'name': u'Using Hive with Existing Files on S3 | Mustard Grain Blog',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'https://blog.mustardgrain.com/2010/09/30/using-hive-with-existing-files-on-s3/'},
#         {u'date_added': u'13115770988780864',
#          u'id': u'170',
#          u'name': u'Hive as a tool for ETL or ELT',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://www.ibm.com/developerworks/library/bd-hivetool/'},
#         {u'date_added': u'13116715835858902',
#          u'id': u'175',
#          u'name': u'secor/DESIGN.md at master \xb7 pinterest/secor',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'https://github.com/pinterest/secor/blob/master/DESIGN.md'},
#         {u'date_added': u'13116977144701799',
#          u'id': u'176',
#          u'name': u'Using Spark SQL for ETL - AWS Big Data Blog',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'https://blogs.aws.amazon.com/bigdata/post/Tx2D93GZRHU3TES/Using-Spark-SQL-for-ETL'},
#         {u'date_added': u'13116977147660594',
#          u'id': u'177',
#          u'name': u'Configuring Snowflake to Communicate with Apache Spark Running on Amazon EMR with Apache Zeppelin \u2013 Snowflake Computing',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'https://support.snowflake.net/hc/en-us/articles/210226946-Configuring-Snowflake-to-Communicate-with-Apache-Spark-Running-on-Amazon-EMR-with-Apache-Zeppelin'},
#         {u'date_added': u'13117155840422665',
#          u'id': u'178',
#          u'name': u'Secure base64 content encoding/decoding',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://www.base64decode.com/'},
#         {u'date_added': u'13117155857473435',
#          u'id': u'179',
#          u'name': u'Best Online JSON Viewer, Beautifier, Formatter, Analyser, Minify, Converter',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://codebeautify.org/jsonviewer'}],
#        u'date_added': u'13114201384215169',
#        u'date_modified': u'13117839163523413',
#        u'id': u'150',
#        u'name': u'Engineering',
#        u'sync_transaction_version': u'331',
#        u'type': u'folder'},
#       {u'date_added': u'13106265146260756',
#        u'id': u'112',
#        u'name': u'',
#        u'sync_transaction_version': u'331',
#        u'type': u'url',
#        u'url': u'https://ancestry.snowflakecomputing.com/console#/warehouses'},
#       {u'date_added': u'13111696009560831',
#        u'id': u'145',
#        u'name': u'Background Tasks',
#        u'sync_transaction_version': u'331',
#        u'type': u'url',
#        u'url': u'http://tableau/#/views/BackgroundTasksforExtracts/BackgroundTasksforExtracts?:iid=1'},
#       {u'date_added': u'13110481253220167',
#        u'id': u'139',
#        u'name': u'Standards',
#        u'sync_transaction_version': u'331',
#        u'type': u'url',
#        u'url': u'http://www.ancestry.com/cs/standards/home'},
#       {u'date_added': u'13105142067235749',
#        u'id': u'100',
#        u'name': u'TP',
#        u'sync_transaction_version': u'494',
#        u'type': u'url',
#        u'url': u'https://ancestry.tpondemand.com/RestUI/Board.aspx?acid=5D6AC326B4D272C23E446C28586BAF51#page=board/4622680486172868341&appConfig=eyJhY2lkIjoiRENCMzMyRURDRjkxRjZERTAzRTEwMkJGNzU4NDlDNTkifQ=='},
#       {u'date_added': u'13099523848906406',
#        u'id': u'7',
#        u'name': u'Treehouse',
#        u'sync_transaction_version': u'331',
#        u'type': u'url',
#        u'url': u'http://treehouse.ancestry.com/Pages/default.aspx'},
#       {u'date_added': u'13100822055706724',
#        u'id': u'26',
#        u'name': u'',
#        u'sync_transaction_version': u'332',
#        u'type': u'url',
#        u'url': u'http://stash/projects/BIT/'},
#       {u'date_added': u'13120355075472172',
#        u'id': u'603',
#        u'name': u'Bit Team Health Tracker - Google Sheets',
#        u'sync_transaction_version': u'356',
#        u'type': u'url',
#        u'url': u'https://docs.google.com/spreadsheets/d/1hXx1st_HGykznu4w3su9V6IZ1ii5YH0kK0DHhHuYf0E/edit#gid=0'}],
#      u'date_added': u'13120354572399137',
#      u'date_modified': u'13120355085957207',
#      u'id': u'597',
#      u'name': u'Ancestry',
#      u'sync_transaction_version': u'335',
#      u'type': u'folder'},
#     {u'children': [{u'children': [{u'date_added': u'13103170972102855',
#          u'id': u'365',
#          u'name': u'The Algorithm Design Manual',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://www.algorist.com/'},
#         {u'date_added': u'13111736762833709',
#          u'id': u'366',
#          u'name': u'Finding Similar Music using Matrix Factorization',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://www.benfrederickson.com/matrix-factorization/'},
#         {u'date_added': u'13115786184928835',
#          u'id': u'367',
#          u'name': u'K Means notebook',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://nbviewer.jupyter.org/github/nborwankar/LearnDataScience/blob/master/notebooks/D3.%20K-Means%20Clustering%20Analysis.ipynb'},
#         {u'date_added': u'13096078782457914',
#          u'id': u'335',
#          u'name': u'Some Important Streaming Algorithms You Should Know About | MapR',
#          u'sync_transaction_version': u'58',
#          u'type': u'url',
#          u'url': u'https://www.mapr.com/blog/some-important-streaming-algorithms-you-should-know-about?utm_campaign=Data%2BElixir&utm_medium=email&utm_source=Data_Elixir_67#.VfLFZdNVhBc'},
#         {u'date_added': u'13090193455368278',
#          u'id': u'301',
#          u'meta_info': {u'stars.flags': u'5',
#           u'stars.id': u'ssc_bc453eab1c112bb4',
#           u'stars.version': u'sync.server.Chrome46'},
#          u'name': u'The Two Egg Problem',
#          u'sync_transaction_version': u'105',
#          u'type': u'url',
#          u'url': u'http://datagenetics.com/blog/july22012/index.html'}],
#        u'date_added': u'13117758020544322',
#        u'date_modified': u'13120351768202392',
#        u'id': u'329',
#        u'name': u'Algorithms',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13071167768292000',
#          u'id': u'318',
#          u'meta_info': {u'stars.id': u'ssc_465c04afefe10c89',
#           u'stars.imageData': u'',
#           u'stars.pageData': u'',
#           u'stars.type': u'2',
#           u'stars.version': u'sync.server.Chrome44'},
#          u'name': u'The Search API | Twitter Developers',
#          u'sync_transaction_version': u'491',
#          u'type': u'url',
#          u'url': u'https://dev.twitter.com/rest/public/search'}],
#        u'date_added': u'13120351635543491',
#        u'date_modified': u'13120351652814843',
#        u'id': u'586',
#        u'name': u'API',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13091743284460521',
#          u'id': u'358',
#          u'name': u'First News App \u2014 First News App documentation',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://first-news-app.readthedocs.org/en/latest/#act-2-hello-flask'},
#         {u'date_added': u'13091313385799953',
#          u'id': u'359',
#          u'name': u'Full Stack Python',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://www.fullstackpython.com/'},
#         {u'date_added': u'13096078702811347',
#          u'id': u'360',
#          u'name': u'Trey Causey \u2013 Software development skills for data scientists',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://treycausey.com/software_dev_skills.html?utm_campaign=Data%2BElixir&utm_medium=email&utm_source=Data_Elixir_67'},
#         {u'date_added': u'13114746920700825',
#          u'id': u'361',
#          u'name': u'Identity & User Management API | Stormpath',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'https://stormpath.com/'},
#         {u'children': [{u'date_added': u'13104985372559016',
#            u'id': u'349',
#            u'name': u'Masonry Pintrest like tiles',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'http://masonry.desandro.com/'},
#           {u'date_added': u'13108975026466289',
#            u'id': u'350',
#            u'name': u'Color wheel | Color schemes - Adobe Color CC',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://color.adobe.com/create/color-wheel/?base=2&rule=Custom&selected=0&name=My%20Color%20Theme&mode=rgb&rgbvalues=0.7,0.49046395158208,0.17998750812217534,0.17476521182305418,0.7080993837090468,0.75,1,0.43555064970377466,0.2808564854858706,0.2323397213843161,0.05162333162510873,0.8,0.22984553141965894,0.08017041517197009,0.7&swatchOrder=0,1,2,3,4'},
#           {u'date_added': u'13109482384097048',
#            u'id': u'351',
#            u'name': u'Cash to Hospitals',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'http://qqpidanlao.github.io/Statsfest/plot/plot5.html'},
#           {u'date_added': u'13109482403239188',
#            u'id': u'352',
#            u'name': u'Salary, jobs and life quality data by Teleport',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://teleport.org/my-cities'},
#           {u'date_added': u'13109488484341347',
#            u'id': u'353',
#            u'name': u'HTML5 UP! Responsive HTML5 and CSS3 Site Templates',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://html5up.net/'},
#           {u'date_added': u'13113969497005941',
#            u'id': u'354',
#            u'name': u'The Twelve-Factor App',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'http://12factor.net/'},
#           {u'date_added': u'13089318986167132',
#            u'id': u'296',
#            u'meta_info': {u'stars.id': u'ssc_fa2302c24622f501',
#             u'stars.version': u'sync.server.Chrome45'},
#            u'name': u'Jekyll Themes',
#            u'sync_transaction_version': u'117',
#            u'type': u'url',
#            u'url': u'http://jekyllthemes.org/page4/'},
#           {u'date_added': u'13109289592230491',
#            u'id': u'131',
#            u'name': u'Beautiful web type \u2014 the best typefaces from the Google web fonts directory',
#            u'sync_transaction_version': u'292',
#            u'type': u'url',
#            u'url': u'http://hellohappy.org/beautiful-web-type/'},
#           {u'date_added': u'13109289797395032',
#            u'id': u'132',
#            u'name': u'Typography Inspiration for the Modern Web \u2192 Typewolf',
#            u'sync_transaction_version': u'293',
#            u'type': u'url',
#            u'url': u'https://www.typewolf.com/'},
#           {u'date_added': u'13109290911830110',
#            u'id': u'133',
#            u'name': u'Unsplash | High-Resolution Photos',
#            u'sync_transaction_version': u'294',
#            u'type': u'url',
#            u'url': u'https://unsplash.com/'},
#           {u'date_added': u'13109291486837634',
#            u'id': u'134',
#            u'name': u'Corporate Site and Technology websites \u2014 siteInspire',
#            u'sync_transaction_version': u'295',
#            u'type': u'url',
#            u'url': u'https://www.siteinspire.com/websites?categories=124+40'},
#           {u'date_added': u'13104522766307071',
#            u'id': u'90',
#            u'name': u'Blackrock Digital',
#            u'sync_transaction_version': u'296',
#            u'type': u'url',
#            u'url': u'https://github.com/BlackrockDigital'}],
#          u'date_added': u'13117758020544622',
#          u'date_modified': u'13120354446157537',
#          u'id': u'339',
#          u'name': u'Inspiration / Resources',
#          u'sync_transaction_version': u'93',
#          u'type': u'folder'},
#         {u'date_added': u'13105140415124199',
#          u'id': u'97',
#          u'name': u'HTML5, CSS3, JS Demos, Creations and Experiments | CSSDeck',
#          u'sync_transaction_version': u'298',
#          u'type': u'url',
#          u'url': u'http://cssdeck.com/'},
#         {u'date_added': u'13104522790853660',
#          u'id': u'91',
#          u'name': u'Edit fiddle - JSFiddle',
#          u'sync_transaction_version': u'300',
#          u'type': u'url',
#          u'url': u'http://jsfiddle.net/jaakkytt/FVyS2/'},
#         {u'date_added': u'13105140425267774',
#          u'id': u'98',
#          u'name': u'Masonry \xb7 Extras',
#          u'sync_transaction_version': u'301',
#          u'type': u'url',
#          u'url': u'http://masonry.desandro.com/extras.html#extra-examples'},
#         {u'date_added': u'13104522695462596',
#          u'id': u'88',
#          u'name': u'What\u2019s New in Bootstrap 4 | Scotch',
#          u'sync_transaction_version': u'305',
#          u'type': u'url',
#          u'url': u'https://scotch.io/bar-talk/whats-new-in-bootstrap-4'},
#         {u'date_added': u'13103320585071842',
#          u'id': u'71',
#          u'name': u'How to Setup Microservices Architecture in Python with ZeroMQ & Docker',
#          u'sync_transaction_version': u'306',
#          u'type': u'url',
#          u'url': u'http://blog.apcelent.com/how-to-setup-microservices-python-zeromq-docker-example.html?utm_source=tw.com&utm_medium=marketing&utm_campaign=blog'},
#         {u'date_added': u'13106330813295286',
#          u'id': u'114',
#          u'name': u'Masonry',
#          u'sync_transaction_version': u'310',
#          u'type': u'url',
#          u'url': u'http://masonry.desandro.com/'},
#         {u'date_added': u'13105482599597710',
#          u'id': u'103',
#          u'name': u'List of Embed Parameters',
#          u'sync_transaction_version': u'311',
#          u'type': u'url',
#          u'url': u'https://onlinehelp.tableau.com/current/online/en-us/embed_list.htm'},
#         {u'date_added': u'13105482604886733',
#          u'id': u'104',
#          u'name': u'Embed Images',
#          u'sync_transaction_version': u'312',
#          u'type': u'url',
#          u'url': u'http://onlinehelp.tableau.com/current/server/en-us/help.htm#embed_ex_img.htm%3FTocPath%3DWork%2520with%2520Views%7CEmbed%2520Views%7CExamples%7C_____8'},
#         {u'date_added': u'13105488869172575',
#          u'id': u'105',
#          u'name': u'Object Naming',
#          u'sync_transaction_version': u'313',
#          u'type': u'url',
#          u'url': u'https://technet.microsoft.com/en-us/library/cc977992.aspx'},
#         {u'date_added': u'13107376110874544',
#          u'id': u'125',
#          u'name': u'Home \xb7 Mottie/tablesorter Wiki',
#          u'sync_transaction_version': u'314',
#          u'type': u'url',
#          u'url': u'https://github.com/Mottie/tablesorter/wiki'},
#         {u'date_added': u'13107392805675028',
#          u'id': u'126',
#          u'name': u'jQuery tablesorter 2.0',
#          u'sync_transaction_version': u'315',
#          u'type': u'url',
#          u'url': u'https://mottie.github.io/tablesorter/docs/index.html#Examples'},
#         {u'date_added': u'13107392813945948',
#          u'id': u'127',
#          u'name': u'Tablesorter demo - JSFiddle',
#          u'sync_transaction_version': u'316',
#          u'type': u'url',
#          u'url': u'http://jsfiddle.net/Mottie/856bzzeL/851/'},
#         {u'date_added': u'13109276434769173',
#          u'id': u'130',
#          u'name': u'osx - OS X: open e-mail client, create new mail and add file as attachment - Stack Overflow',
#          u'sync_transaction_version': u'317',
#          u'type': u'url',
#          u'url': u'http://stackoverflow.com/questions/5351541/os-x-open-e-mail-client-create-new-mail-and-add-file-as-attachment'}],
#        u'date_added': u'13117758020544460',
#        u'date_modified': u'13120354557775879',
#        u'id': u'334',
#        u'name': u'App dev',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13096076430531383',
#          u'id': u'330',
#          u'name': u'Drake',
#          u'sync_transaction_version': u'72',
#          u'type': u'url',
#          u'url': u'https://www.factual.com/blog/introducing-drake-a-kind-of-make-for-data'},
#         {u'children': [{u'date_added': u'13078425701425000',
#            u'id': u'522',
#            u'meta_info': {u'stars.id': u'c_a1fkiaqy22lw',
#             u'stars.imageData': u'',
#             u'stars.note': u'',
#             u'stars.pageData': u'',
#             u'stars.type': u'2',
#             u'stars.version': u'crx.2.2015.522.11440'},
#            u'name': u"Scheduling R Tasks via Windows Task Scheduler | TRinker's R Blog",
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://trinkerrstuff.wordpress.com/2015/02/11/scheduling-r-tasks-via-windows-task-scheduler/'},
#           {u'date_added': u'13078425736899648',
#            u'id': u'523',
#            u'meta_info': {u'stars.id': u'c_ax8siaqy2u0e',
#             u'stars.imageData': u'EoIBCnpodHRwOi8vY2RuNS5ob3d0b2dlZWsuY29tL3RodW1iY2FjaGUvMjgwLzE2MC9lZTE2MTMwMjc5ZGRlOGMyOWQ5NzIyNzQxZDBlMmY3Yy93cC1jb250ZW50L3VwbG9hZHMvMjAxNC8wNC9jbGlwX2ltYWdlMDAxLmpwZxCYAhigARoA',
#             u'stars.note': u'',
#             u'stars.pageData': u'EiJXYWtlIHRoZSBjb21wdXRlciB0byBydW4gdGhpcyB0YXNr',
#             u'stars.type': u'2',
#             u'stars.version': u'sync.server.Chrome43'},
#            u'name': u'Windows Admin: Using Task Scheduler to Run Processes Later',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'http://www.howtogeek.com/school/using-windows-admin-tools-like-a-pro/lesson2/all/'},
#           {u'date_added': u'13078425749391000',
#            u'id': u'524',
#            u'meta_info': {u'stars.flags': u'0',
#             u'stars.id': u'c_14esiaqy33on',
#             u'stars.note': u'',
#             u'stars.pageData': u'',
#             u'stars.type': u'2'},
#            u'name': u'\u201cWake the computer to run this task\u201d function in Task scheduler may not work as expected',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://support.microsoft.com/en-us/kb/2586195'},
#           {u'date_added': u'13079736157975721',
#            u'id': u'525',
#            u'meta_info': {u'stars.id': u'ssc_0a268c9af08e36f0',
#             u'stars.version': u'sync.server.Chrome43'},
#            u'name': u'Ubuntu_as_Guest_OS - Community Help Wiki',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://help.ubuntu.com/community/Ubuntu_as_Guest_OS'},
#           {u'date_added': u'13079736179231776',
#            u'id': u'526',
#            u'meta_info': {u'stars.flags': u'5',
#             u'stars.id': u'ssc_0caea852967779c5',
#             u'stars.version': u'sync.server.Chrome43'},
#            u'name': u'installation - How to Install Ubuntu server inside Windows - Ask Ubuntu',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'http://askubuntu.com/questions/144473/how-to-install-ubuntu-server-inside-windows'},
#           {u'date_added': u'13080296494484583',
#            u'id': u'527',
#            u'meta_info': {u'stars.id': u'ssc_d3e4cc1f491df361',
#             u'stars.version': u'sync.server.Chrome43'},
#            u'name': u'R CMD on Windows 7 Error - "R" is not recognized as an internal or external command, - Stack Overflow',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'http://stackoverflow.com/questions/10077689/r-cmd-on-windows-7-error-r-is-not-recognized-as-an-internal-or-external-comm'},
#           {u'date_added': u'13080322532573254',
#            u'id': u'528',
#            u'meta_info': {u'stars.flags': u'5',
#             u'stars.id': u'ssc_5715f5f89ccb42d5',
#             u'stars.version': u'sync.server.Chrome43'},
#            u'name': u'(1) Error in check_twitter_oauth( ) \xb7 Issue #90 \xb7 geoffjentry/twitteR',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'https://github.com/geoffjentry/twitteR/issues/90'},
#           {u'date_added': u'13080755716120536',
#            u'id': u'529',
#            u'meta_info': {u'stars.id': u'ssc_890dbeaf970f65bc',
#             u'stars.version': u'sync.server.Chrome43'},
#            u'name': u'Power Options - Add or Remove "Allow wake timers"',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'http://www.eightforums.com/tutorials/50074-power-options-add-remove-allow-wake-timers.html'},
#           {u'date_added': u'13081409189504643',
#            u'id': u'530',
#            u'meta_info': {u'stars.id': u'ssc_0bfc0422183f2ebd',
#             u'stars.version': u'sync.server.Chrome43'},
#            u'name': u'DataWeave \u2022 Building a Twitter Sentiment Analysis App using R',
#            u'sync_transaction_version': u'3',
#            u'type': u'url',
#            u'url': u'http://blog.dataweave.in/post/96618078833/building-a-twitter-sentiment-analysis-app-using-r'}],
#          u'date_added': u'13117758020544086',
#          u'date_modified': u'13117758020544086',
#          u'id': u'319',
#          u'meta_info': {u'stars.description': u'',
#           u'stars.id': u'ssf_14270a80bfd32bd3',
#           u'stars.isPublic': u'false',
#           u'stars.isSynced': u'true'},
#          u'name': u'PC Automation w/ R',
#          u'sync_transaction_version': u'100',
#          u'type': u'folder'},
#         {u'date_added': u'13097658401780051',
#          u'id': u'283',
#          u'name': u'Building Data Pipelines with Python and Luigi \u2013 Marco Bonzanini',
#          u'sync_transaction_version': u'130',
#          u'type': u'url',
#          u'url': u'http://marcobonzanini.com/2015/10/24/building-data-pipelines-with-python-and-luigi/?utm_content=buffer94385&utm_medium=social&utm_source=twitter.com&utm_campaign=buffer'},
#         {u'date_added': u'13104965263770257',
#          u'id': u'94',
#          u'name': u'How do you use python to automate tasks in life or at work? : Python',
#          u'sync_transaction_version': u'265',
#          u'type': u'url',
#          u'url': u'https://www.reddit.com/r/Python/comments/4edpl0/how_do_you_use_python_to_automate_tasks_in_life/'}],
#        u'date_added': u'13120351377252079',
#        u'date_modified': u'13120353522884525',
#        u'id': u'583',
#        u'name': u'Automation / ETL',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13107999368116405',
#          u'id': u'344',
#          u'name': u'python - Trouble installing scipy in virtualenv on a amazon ec2 linux micro instance - Stack Overflow',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://stackoverflow.com/questions/19595944/trouble-installing-scipy-in-virtualenv-on-a-amazon-ec2-linux-micro-instance?rq=1'},
#         {u'date_added': u'13107999374889149',
#          u'id': u'345',
#          u'name': u'python - Installing modules through pip in a virtualenv in an AWS Lambda function - no error message - Stack Overflow',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://stackoverflow.com/questions/34957434/installing-modules-through-pip-in-a-virtualenv-in-an-aws-lambda-function-no-er'},
#         {u'date_added': u'13108024004787877',
#          u'id': u'346',
#          u'name': u'python - Cron and virtualenv - Stack Overflow',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://stackoverflow.com/questions/3287038/cron-and-virtualenv'},
#         {u'date_added': u'13108025942737019',
#          u'id': u'347',
#          u'name': u'Find and kill a process in one line using bash and regex - Stack Overflow',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://stackoverflow.com/questions/3510673/find-and-kill-a-process-in-one-line-using-bash-and-regex?answertab=active#tab-top'}],
#        u'date_added': u'13117758020544708',
#        u'date_modified': u'13117758020544708',
#        u'id': u'341',
#        u'name': u'AWS',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13103085345214746',
#          u'id': u'355',
#          u'name': u'Airbnb New User Bookings, Winner\u2019s Interview: 3rd place: Sandro Vega Pons | no free hunch',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://blog.kaggle.com/2016/03/07/airbnb-new-user-bookings-winners-interview-3rd-place-sandro-vega-pons/'},
#         {u'date_added': u'13095800596084950',
#          u'id': u'306',
#          u'name': u'www.contrib.andrew.cmu.edu/~kdagrawa/documents/waterpump.pdf',
#          u'sync_transaction_version': u'113',
#          u'type': u'url',
#          u'url': u'http://www.contrib.andrew.cmu.edu/~kdagrawa/documents/waterpump.pdf'},
#         {u'date_added': u'13089312963743956',
#          u'id': u'308',
#          u'name': u'Competition: Pump it Up: Data Mining the Water Table',
#          u'sync_transaction_version': u'115',
#          u'type': u'url',
#          u'url': u'http://www.drivendata.org/competitions/7/'},
#         {u'date_added': u'13102627823839808',
#          u'id': u'61',
#          u'name': u'Competition: From Fog Nets to Neural Nets',
#          u'sync_transaction_version': u'260',
#          u'type': u'url',
#          u'url': u'https://www.drivendata.org/competitions/9/'}],
#        u'date_added': u'13117758020544602',
#        u'date_modified': u'13120353483636139',
#        u'id': u'338',
#        u'name': u'Competitions',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13084492674955189',
#          u'id': u'324',
#          u'meta_info': {u'stars.id': u'ssc_31e2d32c1992cd05',
#           u'stars.version': u'sync.server.Chrome44'},
#          u'name': u'Useless Press: World Leader Tips',
#          u'sync_transaction_version': u'61',
#          u'type': u'url',
#          u'url': u'http://uselesspress.org/things/world-leader-tips/'}],
#        u'date_added': u'13120351255848274',
#        u'date_modified': u'13120351263272997',
#        u'id': u'581',
#        u'name': u'Cool projects',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'children': [{u'date_added': u'13124403603230136',
#            u'id': u'670',
#            u'name': u'Image Classification and Segmentation with Tensorflow and TF-Slim',
#            u'sync_transaction_version': u'499',
#            u'type': u'url',
#            u'url': u'http://warmspringwinds.github.io/tensorflow/tf-slim/2016/10/30/image-classification-and-segmentation-using-tensorflow-and-tf-slim/'},
#           {u'date_added': u'13124403631913089',
#            u'id': u'672',
#            u'name': u'Learning to Segment - Research at Facebook',
#            u'sync_transaction_version': u'503',
#            u'type': u'url',
#            u'url': u'https://research.facebook.com/blog/learning-to-segment/'},
#           {u'date_added': u'13124403635165130',
#            u'id': u'673',
#            u'name': u'Image-to-Image Translation with Conditional Adversarial Networks',
#            u'sync_transaction_version': u'505',
#            u'type': u'url',
#            u'url': u'https://phillipi.github.io/pix2pix/'}],
#          u'date_added': u'13124403629415058',
#          u'date_modified': u'13124403635165130',
#          u'id': u'671',
#          u'name': u'Image segmentation',
#          u'sync_transaction_version': u'500',
#          u'type': u'folder'},
#         {u'date_added': u'13107153290688284',
#          u'id': u'340',
#          u'name': u'Draper Satellite Image Chronology | Kaggle',
#          u'sync_transaction_version': u'80',
#          u'type': u'url',
#          u'url': u'https://www.kaggle.com/bkamphaus/draper-satellite-image-chronology/exploratory-image-analysis/'}],
#        u'date_added': u'13120351424705043',
#        u'date_modified': u'13120351434598258',
#        u'id': u'585',
#        u'name': u'CV / OCR',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13115795561212625',
#          u'id': u'362',
#          u'name': u'The Data Journalism Handbook',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://datajournalismhandbook.org/1.0/en/'},
#         {u'date_added': u'13119123921269757',
#          u'id': u'569',
#          u'name': u'Now this is a story all about how we found the Wet Princes of Bel Air | Reveal',
#          u'sync_transaction_version': u'32',
#          u'type': u'url',
#          u'url': u'https://www.revealnews.org/blog/now-this-is-a-story-all-about-how-we-found-the-wet-princes-of-bel-air/?utm_campaign=Data%2BElixir&utm_medium=email&utm_source=Data_Elixir_98'}],
#        u'date_added': u'13117758020544441',
#        u'date_modified': u'13119123921269757',
#        u'id': u'333',
#        u'name': u'Data Journalism',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13113552169178103',
#          u'id': u'364',
#          u'name': u"Giving back with code | It's a Locke",
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://itsalocke.com/giving-back-code/'},
#         {u'date_added': u'13081625698160595',
#          u'id': u'534',
#          u'meta_info': {u'stars.id': u'ssc_e3e3f36368e23cd6',
#           u'stars.version': u'sync.server.Chrome44'},
#          u'name': u'DataLook | Blog',
#          u'sync_transaction_version': u'103',
#          u'type': u'url',
#          u'url': u'http://blog.datalook.io/definitive-guide-data-science-good/?utm_campaign=Data%2BElixir&utm_medium=email&utm_source=Data_Elixir_44'},
#         {u'date_added': u'13055620471804000',
#          u'id': u'291',
#          u'meta_info': {u'stars.id': u'ssc_b1894c59194457df',
#           u'stars.isSynced': u'true',
#           u'stars.pageData': u'Ig5kVWxMdE8zeF80d3NnTQ==',
#           u'stars.type': u'2'},
#          u'name': u'Data for Good: Share data-driven projects for social good',
#          u'sync_transaction_version': u'127',
#          u'type': u'url',
#          u'url': u'http://dataforgood.co/top/30'}],
#        u'date_added': u'13117758020544401',
#        u'date_modified': u'13120351957946796',
#        u'id': u'331',
#        u'name': u'Data Science for Social Good',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13101035309879339',
#          u'id': u'342',
#          u'name': u'MongoDB life-saver',
#          u'sync_transaction_version': u'67',
#          u'type': u'url',
#          u'url': u'http://www.marcusoft.net/2014/05/mongodb-and-10309-unable-to-createopen.html'}],
#        u'date_added': u'13120351342680489',
#        u'date_modified': u'13120351364380130',
#        u'id': u'582',
#        u'name': u'Databases',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13064967192717000',
#          u'id': u'317',
#          u'meta_info': {u'stars.id': u'ssc_eea26cade71999d6',
#           u'stars.imageData': u'',
#           u'stars.pageData': u'Ig42X2gybHlLN2ZRdkMzTQ==',
#           u'stars.type': u'2',
#           u'stars.version': u'sync.server.Chrome40'},
#          u'name': u'Google Maps distance function for Excel | oCoCarbon',
#          u'sync_transaction_version': u'81',
#          u'type': u'url',
#          u'url': u'http://oco-carbon.com/coding/google-excel-distance-function/'}],
#        u'date_added': u'13120351402037055',
#        u'date_modified': u'13120351438859580',
#        u'id': u'584',
#        u'name': u'Excel',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13077825479394000',
#          u'id': u'407',
#          u'meta_info': {u'stars.id': u'c_fzcbiah0p8bs',
#           u'stars.imageData': u'',
#           u'stars.isSynced': u'true',
#           u'stars.note': u'',
#           u'stars.pageData': u'EqEBVGhpcyBib29rIGlzIHRyYW5zbGF0ZWQgaW50byBEZXV0c2NoLCDnroDkvZPkuK3mlocsIOato+mrlOS4reaWhywgRnJhbsOnYWlzLCDml6XmnKzoqp4sIE5lZGVybGFuZHMsINCg0YPRgdGB0LrQuNC5LCDtlZzqta3slrQsIFBvcnR1Z3XDqnMgKEJyYXNpbCkgYW5kIMSMZcWhdGluYS4iDlRpbDN0VzQ0SHpSSWtN',
#           u'stars.type': u'2'},
#          u'name': u'Git -M',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'https://git-scm.com/book/en/v2/Git-Basics-Recording-Changes-to-the-Repository'},
#         {u'date_added': u'13065773201684000',
#          u'id': u'408',
#          u'meta_info': {u'stars.id': u'ssc_f3a71a4218629fe3',
#           u'stars.imageData': u'',
#           u'stars.isSynced': u'true',
#           u'stars.pageData': u'',
#           u'stars.type': u'2'},
#          u'name': u'A basic tutorial to version control using git | sample(ECOLOGY)',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://jonlefcheck.net/2013/11/04/a-basic-tutorial-to-version-control-using-git/'},
#         {u'date_added': u'13073515759847000',
#          u'id': u'409',
#          u'meta_info': {u'stars.id': u'ssc_64478633b5a81c06',
#           u'stars.imageData': u'',
#           u'stars.isSynced': u'true',
#           u'stars.pageData': u'Ig5HUzlpUERkTjRuR3VMTQ==',
#           u'stars.type': u'2'},
#          u'name': u'git - How to commit only modified (and not new or deleted) files? - Stack Overflow',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://stackoverflow.com/questions/4873976/how-to-commit-only-modified-and-not-new-or-deleted-files'},
#         {u'date_added': u'13085983826590344',
#          u'id': u'410',
#          u'name': u'Command Line',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://www.westwind.com/reference/os-x/commandline/files-folders.html#mv'},
#         {u'date_added': u'13096075902703240',
#          u'id': u'292',
#          u'name': u'README.md template',
#          u'sync_transaction_version': u'120',
#          u'type': u'url',
#          u'url': u'https://gist.github.com/jxson/1784669'}],
#        u'date_added': u'13117758020544248',
#        u'date_modified': u'13120351921786320',
#        u'id': u'325',
#        u'name': u'Git / Bash',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13097007291929029',
#          u'id': u'356',
#          u'name': u'GA tech MS Computer Science Machine Learning',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://www.omscs.gatech.edu/program/'},
#         {u'date_added': u'13059104349000673',
#          u'id': u'316',
#          u'meta_info': {u'stars.flags': u'5',
#           u'stars.id': u'ssc_6507c532e9dea90e',
#           u'stars.version': u'sync.server.Chrome40'},
#          u'name': u'Nebraska DS',
#          u'sync_transaction_version': u'83',
#          u'type': u'url',
#          u'url': u'http://www.unomaha.edu/mahbubulmajumder/data-science/fall-2014/index.html'},
#         {u'date_added': u'13117183957346088',
#          u'id': u'343',
#          u'name': u'70+ Resources for Transitioning to a Data Science Career',
#          u'sync_transaction_version': u'94',
#          u'type': u'url',
#          u'url': u'https://blog.modeanalytics.com/data-science-career/?utm_content=buffer24491&utm_medium=social&utm_source=twitter.com&utm_campaign=buffer'},
#         {u'date_added': u'13096077268837484',
#          u'id': u'293',
#          u'name': u'How to describe your Personal Projects on your Data Science resume | DataScienceResume.com',
#          u'sync_transaction_version': u'121',
#          u'type': u'url',
#          u'url': u'http://datascienceresume.com/advice/how-to-describe-your-personal-projects-on-your-data-science-resume'},
#         {u'date_added': u'13097029202423820',
#          u'id': u'294',
#          u'name': u'Resources - Google Sheets',
#          u'sync_transaction_version': u'122',
#          u'type': u'url',
#          u'url': u'https://docs.google.com/spreadsheets/d/1gNHiroajQR6pPvgLdG1j4r-QCPvlMBSi0LfXZDeFs0g/edit#gid=0'},
#         {u'date_added': u'13111596392560239',
#          u'id': u'295',
#          u'name': u'Graduate School - Letters of Recommendation | Career Center',
#          u'sync_transaction_version': u'123',
#          u'type': u'url',
#          u'url': u'https://career.berkeley.edu/Grad/GradLetter'},
#         {u'date_added': u'13117980898692477',
#          u'id': u'557',
#          u'name': u'Frequently Asked Questions | Master of Science in Data Science',
#          u'sync_transaction_version': u'124',
#          u'type': u'url',
#          u'url': u'http://galvanizeu.newhaven.edu/frequently-asked-questions/'},
#         {u'date_added': u'13117981001504989',
#          u'id': u'558',
#          u'name': u'Degree Requirements | Master of Science in Business Analytics',
#          u'sync_transaction_version': u'125',
#          u'type': u'url',
#          u'url': u'http://eccles.utah.edu/programs/master-of-science-in-business-analytics/academics/degree-requirements/'},
#         {u'date_added': u'13122145757020958',
#          u'id': u'639',
#          u'name': u'The Open Source Data Science Masters by datasciencemasters',
#          u'sync_transaction_version': u'419',
#          u'type': u'url',
#          u'url': u'http://datasciencemasters.org/'}],
#        u'date_added': u'13117758020544584',
#        u'date_modified': u'13122404605085362',
#        u'id': u'337',
#        u'name': u'Graduate programs',
#        u'sync_transaction_version': u'262',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13076796100554478',
#          u'id': u'369',
#          u'meta_info': {u'stars.id': u'c_8m1qi9zzu2lz',
#           u'stars.imageData': u'EloKUmh0dHA6Ly9yYXlsaS5uZXQvYmxvZy93cC1jb250ZW50L3VwbG9hZHMvMjAxNS8wNS90b3BfMTBfZGF0YV9taW5pbmdfYWxnb3JpdGhtcy5qcGcQ7gUYrAIaAA==',
#           u'stars.isSynced': u'true',
#           u'stars.note': u'',
#           u'stars.pageData': u'Ep0BVG9kYXksIEnigJltIGdvaW5nIHRvIGV4cGxhaW4gaW4gcGxhaW4gRW5nbGlzaCB0aGUgdG9wIDEwIG1vc3QgaW5mbHVlbnRpYWwgZGF0YSBtaW5pbmcgYWxnb3JpdGhtcyBhcyB2b3RlZCBvbiBieSAzIHNlcGFyYXRlIHBhbmVscyBpbiB0aGlzIDIwMDcgc3VydmV5IHBhcGVyLg==',
#           u'stars.type': u'2'},
#          u'name': u'Top 10 data mining algorithms in plain English | rayli.net',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://rayli.net/blog/data/top-10-data-mining-algorithms-in-plain-english/?utm_campaign=Data%2BElixir&utm_source=Data_Elixir_36'},
#         {u'date_added': u'13094235733150517',
#          u'id': u'370',
#          u'name': u'Principal component analysis | EFavDB',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://efavdb.com/principal-component-analysis/'},
#         {u'date_added': u'13080957682505235',
#          u'id': u'371',
# ...
#          u'type': u'url',
#          u'url': u'https://www.groovehq.com/blog/business-email-templates'}],
#        u'date_added': u'13121379247810100',
#        u'date_modified': u'13124302901587635',
#        u'id': u'615',
#        u'name': u'Mealio',
#        u'sync_transaction_version': u'377',
#        u'type': u'folder'}],
#      u'date_added': u'13117758020531652',
#      u'date_modified': u'13120354709284465',
#      u'id': u'245',
#      u'name': u'Projects',
#      u'sync_transaction_version': u'335',
#      u'type': u'folder'},
#     {u'children': [{u'date_added': u'13095599336926534',
#        u'id': u'268',
#        u'name': u'5 Texts You Should Send to Your Partner Every Day | Psychology Today',
#        u'sync_transaction_version': u'3',
#        u'type': u'url',
#        u'url': u'https://www.psychologytoday.com/blog/joyful-parenting/201512/5-texts-you-should-send-your-partner-every-day'},
#       {u'date_added': u'13096077188402419',
#        u'id': u'269',
#        u'meta_info': {u'stars.id': u'c_8m1qi9zzu2lz',
#         u'stars.imageData': u'EloKUmh0dHA6Ly9yYXlsaS5uZXQvYmxvZy93cC1jb250ZW50L3VwbG9hZHMvMjAxNS8wNS90b3BfMTBfZGF0YV9taW5pbmdfYWxnb3JpdGhtcy5qcGcQ7gUYrAIaAA==',
#         u'stars.isSynced': u'true',
#         u'stars.note': u'',
#         u'stars.pageData': u'Ep0BVG9kYXksIEnigJltIGdvaW5nIHRvIGV4cGxhaW4gaW4gcGxhaW4gRW5nbGlzaCB0aGUgdG9wIDEwIG1vc3QgaW5mbHVlbnRpYWwgZGF0YSBtaW5pbmcgYWxnb3JpdGhtcyBhcyB2b3RlZCBvbiBieSAzIHNlcGFyYXRlIHBhbmVscyBpbiB0aGlzIDIwMDcgc3VydmV5IHBhcGVyLg==',
#         u'stars.type': u'2'},
#        u'name': u'Top 10 data mining algorithms in plain English | rayli.net',
#        u'sync_transaction_version': u'3',
#        u'type': u'url',
#        u'url': u'http://rayli.net/blog/data/top-10-data-mining-algorithms-in-plain-english/?utm_campaign=Data%2BElixir&utm_source=Data_Elixir_36'},
#       {u'date_added': u'13096077207167695',
#        u'id': u'270',
#        u'name': u'Understanding the Bias-Variance Tradeoff',
#        u'sync_transaction_version': u'3',
#        u'type': u'url',
#        u'url': u'http://scott.fortmann-roe.com/docs/BiasVariance.html'},
#       {u'date_added': u'13096077797287041',
#        u'id': u'271',
#        u'name': u'Interview prep - Google Sheets',
#        u'sync_transaction_version': u'3',
#        u'type': u'url',
#        u'url': u'https://docs.google.com/spreadsheets/d/1xw--M_pWiM_CwAPCxcWm9mP1flu9mE1NVpjwqJId9qQ/edit#gid=1032829688'},
#       {u'date_added': u'13096078822115767',
#        u'id': u'272',
#        u'name': u'Great Notebooks',
#        u'sync_transaction_version': u'3',
#        u'type': u'url',
#        u'url': u'https://github.com/donnemartin/data-science-ipython-notebooks?utm_campaign=Data%2BElixir&utm_medium=email&utm_source=Data_Elixir_67#mapreduce-python'},
#       {u'date_added': u'13096500675025080',
#        u'id': u'273',
#        u'name': u"Pivot Tables in Python - O'Reilly Media",
#        u'sync_transaction_version': u'3',
#        u'type': u'url',
#        u'url': u'https://www.oreilly.com/learning/pivot-tables'},
#       {u'date_added': u'13097030283460054',
#        u'id': u'274',
#        u'name': u'BuzzFeedNews',
#        u'sync_transaction_version': u'3',
#        u'type': u'url',
#        u'url': u'https://github.com/BuzzFeedNews'},
#       {u'date_added': u'13097197022934060',
#        u'id': u'275',
#        u'name': u'Data Engineer / Scientist - Jobs at Zapier - Zapier',
#        u'sync_transaction_version': u'3',
#        u'type': u'url',
#        u'url': u'https://zapier.com/jobs/data-engineer-scientist-winter-2016/'},
#       {u'date_added': u'13097301525268298',
#        u'id': u'276',
#        u'name': u'(4) Answers - Learn Data Science - Quora',
#        u'sync_transaction_version': u'3',
#        u'type': u'url',
#        u'url': u'https://datascienceinterview.quora.com/Answers-1'},
#       {u'date_added': u'13101282913526854',
#        u'id': u'277',
#        u'name': u'Python for Programmers \u2014 Rustyrazorblade',
#        u'sync_transaction_version': u'3',
#        u'type': u'url',
#        u'url': u'http://rustyrazorblade.com/2014/08/python-for-programmers/'},
#       {u'date_added': u'13120250927673824',
#        u'id': u'575',
#        u'name': u'airbnb/caravel: Caravel is a data exploration platform designed to be visual, intuitive, and interactive',
#        u'sync_transaction_version': u'42',
#        u'type': u'url',
#        u'url': u'https://github.com/airbnb/caravel'},
#       {u'children': [{u'date_added': u'13079637190374276',
#          u'id': u'278',
#          u'meta_info': {u'stars.id': u'ssc_aad842744427faa5',
#           u'stars.isSynced': u'true'},
#          u'name': u'rikturr.com | The Wonderful Works of Aaron Richter | Communicating Experimental Results with R',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://rikturr.com/blog/communicating-experimental-results-with-r/'},
#         {u'date_added': u'13089340956787897',
#          u'id': u'279',
#          u'name': u'Pythonic Perambulations',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'https://jakevdp.github.io/'},
#         {u'date_added': u'13096077396579661',
#          u'id': u'280',
#          u'name': u'FlowingData',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://flowingdata.com/'},
#         {u'date_added': u'13096653051630608',
#          u'id': u'281',
#          u'name': u'DataScience+ Learn R programming for data science',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://datascienceplus.com/'},
#         {u'date_added': u'13097357789731085',
#          u'id': u'282',
#          u'name': u'Anne Stevens | Creative Technology',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://stevensanne.com/blog/'},
#         {u'date_added': u'13097659181590073',
#          u'id': u'284',
#          u'name': u'Mining Twitter Data with Python (Part 1: Collecting data) \u2013 Marco Bonzanini',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://marcobonzanini.com/2015/03/02/mining-twitter-data-with-python-part-1/'},
#         {u'date_added': u'13099961941085107',
#          u'id': u'285',
#          u'name': u'Shatnu Python',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://pythonforengineers.com/'},
#         {u'date_added': u'13099967828800455',
#          u'id': u'286',
#          u'name': u"StoryCorps: Even Seizures Can't Slow This Sixth Grader: 'Nothing Can Stop Me!' : NPR",
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://www.npr.org/2016/02/12/466414706/even-seizures-cant-slow-this-sixth-grader-nothing-can-stop-me'},
#         {u'date_added': u'13101689551061572',
#          u'id': u'287',
#          u'name': u'DogDogFish | Data Science, amongst other things.',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://dogdogfish.com/'},
#         {u'date_added': u'13101883236853412',
#          u'id': u'288',
#          u'name': u'brandonrose.org',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://brandonrose.org/'},
#         {u'date_added': u'13108794734942630',
#          u'id': u'289',
#          u'name': u'Denis Papathanasiou Blog',
#          u'sync_transaction_version': u'3',
#          u'type': u'url',
#          u'url': u'http://denis.papathanasiou.org/programming.html'},
#         {u'date_added': u'13119125313460164',
#          u'id': u'568',
#          u'name': u"Curtis Miller's Personal Website | Curtis Miller's personal website, with resume, portfolio, blog, etc.",
#          u'sync_transaction_version': u'32',
#          u'type': u'url',
#          u'url': u'https://ntguardian.wordpress.com/'},
#         {u'date_added': u'13119599796485559',
#          u'id': u'572',
#          u'name': u'How Elon Musk Started - His Life Visualized',
#          u'sync_transaction_version': u'33',
#          u'type': u'url',
#          u'url': u'http://fundersandfounders.com/how-elon-musk-started/'},
#         {u'date_added': u'13120242043465067',
#          u'id': u'573',
#          u'name': u'Scaling Knowledge at Airbnb \u2013 Airbnb Engineering & Data Science \u2013 Medium',
#          u'sync_transaction_version': u'37',
#          u'type': u'url',
#          u'url': u'https://medium.com/airbnb-engineering/scaling-knowledge-at-airbnb-875d73eff091#.j7h0wdx32'},
#         {u'date_added': u'13100813132419986',
#          u'id': u'25',
#          u'name': u'Marco Bonzanini \u2013 Tech Diary',
#          u'sync_transaction_version': u'238',
#          u'type': u'url',
#          u'url': u'http://marcobonzanini.com/'},
#         {u'date_added': u'13106328935322037',
#          u'id': u'113',
#          u'name': u'Algorithm Visualization \u2014 John Walley',
#          u'sync_transaction_version': u'239',
#          u'type': u'url',
#          u'url': u'http://www.walley.org.uk/blog/2016/4/18/algorithm-visualization'},
#         {u'date_added': u'13120354878312474',
#          u'id': u'599',
#          u'name': u'Python Programming - Jeff Knupp',
#          u'sync_transaction_version': u'344',
#          u'type': u'url',
#          u'url': u'https://jeffknupp.com/blog/'},
#         {u'date_added': u'13122404605085362',
#          u'id': u'640',
#          u'name': u'Data Piques',
#          u'sync_transaction_version': u'423',
#          u'type': u'url',
#          u'url': u'http://blog.ethanrosenthal.com/'},
#         {u'date_added': u'13123272122309386',
#          u'id': u'652',
#          u'name': u'Analyzing Housing Prices in Berkeley - The Sopranos, Silicon Valley, and Summer Afternoons',
#          u'sync_transaction_version': u'462',
#          u'type': u'url',
#          u'url': u'http://aakashjapi.com/housing-prices-in-berkeley/'},
#         {u'date_added': u'13123272140951055',
#          u'id': u'653',
#          u'name': u'Data Piques | Learning to Rank Sketchfab Models with LightFM',
#          u'sync_transaction_version': u'464',
#          u'type': u'url',
#          u'url': u'http://blog.ethanrosenthal.com/2016/11/07/implicit-mf-part-2/'},
#         {u'date_added': u'13123289448347866',
#          u'id': u'654',
#          u'name': u'Learning With Data',
#          u'sync_transaction_version': u'467',
#          u'type': u'url',
#          u'url': u'http://learningwithdata.com/'}],
#        u'date_added': u'13117758020530999',
#        u'date_modified': u'13123289731889941',
#        u'id': u'236',
#        u'name': u'Great Blogs',
#        u'sync_transaction_version': u'224',
#        u'type': u'folder'},
#       {u'children': [{u'date_added': u'13120593712652144',
#          u'id': u'609',
#          u'name': u'The \u2018Insight-Driven Business\u2019: How to Become a Master of the Data Universe',
#          u'sync_transaction_version': u'364',
#          u'type': u'url',
#          u'url': u'http://www.enterprisetech.com/2016/10/03/insight-driven-business-become-master-data-universe/'}],
#        u'date_added': u'13120593710143559',
#        u'date_modified': u'13120773907600575',
#        u'id': u'608',
#        u'name': u'Strata Hadoop 2016',
#        u'sync_transaction_version': u'361',
#        u'type': u'folder'}],
#      u'date_added': u'13117758020531029',
#      u'date_modified': u'13120353159308834',
#      u'id': u'237',
#      u'name': u'Review',
#      u'sync_transaction_version': u'335',
#      u'type': u'folder'},
#     {u'date_added': u'13106679123392979',
#      u'id': u'121',
#      u'name': u'Fount',
#      u'sync_transaction_version': u'335',
#      u'type': u'url',
#      u'url': u'javascript:(function()%7Bif(!document.getElementById(%27fountscript%27))%7Bvar%20founts%3Ddocument.createElement(%27script%27)%3Bfounts.src%3D%27https://fount.artequalswork.com/fount.js%27%3Bfounts.id%3D%27fountscript%27%3Bdocument.body.appendChild(founts)%3B%7D%7D)()%3B'},
#     {u'date_added': u'13121403055870948',
#      u'id': u'619',
#      u'name': u'Heart Felt ornaments',
#      u'sync_transaction_version': u'387',
#      u'type': u'url',
#      u'url': u'https://amber-cheever.squarespace.com/'},
#     {u'date_added': u'13121642493094516',
#      u'id': u'626',
#      u'name': u'Talk Python Training',
#      u'sync_transaction_version': u'420',
#      u'type': u'url',
#      u'url': u'https://training.talkpython.fm/courses/details/python-for-entrepreneurs-build-and-launch-your-online-business'},
#     {u'date_added': u'13121800549049742',
#      u'id': u'629',
#      u'name': u'NiFi',
#      u'sync_transaction_version': u'404',
#      u'type': u'url',
#      u'url': u'https://prdslsldsafht130.myfamilysouth.com:9443/nifi/'},
#     {u'date_added': u'13122018512028860',
#      u'id': u'634',
#      u'name': u'SVG Crowbar',
#      u'sync_transaction_version': u'414',
#      u'type': u'url',
#      u'url': u'javascript:javascript:%20(function%20()%20%7B%20var%20e%20%3D%20document.createElement(%27script%27)%3B%20e.setAttribute(%27src%27,%20%27https://nytimes.github.io/svg-crowbar/svg-crowbar.js%27)%3B%20e.setAttribute(%27class%27,%20%27svg-crowbar%27)%3B%20document.body.appendChild(e)%3B%20%7D)()%3B'},
#     {u'children': [{u'date_added': u'13123922467135391',
#        u'id': u'660',
#        u'name': u'My Tasks in Front Analytics - Asana',
#        u'sync_transaction_version': u'480',
#        u'type': u'url',
#        u'url': u'https://app.asana.com/0/212441862219272/list'},
#       {u'date_added': u'13124056403970532',
#        u'id': u'663',
#        u'name': u'Dan McKinley :: Choose Boring Technology',
#        u'sync_transaction_version': u'489',
#        u'type': u'url',
#        u'url': u'http://mcfunley.com/choose-boring-technology'},
#       {u'date_added': u'13124433761421358',
#        u'id': u'674',
#        u'name': u'Prework - TIY Durham Python 2015-08',
#        u'sync_transaction_version': u'506',
#        u'type': u'url',
#        u'url': u'http://tiyd-python-2015-08.github.io/pages/prework.html'},
#       {u'date_added': u'13124433777306846',
#        u'id': u'675',
#        u'name': u'Data Analytics Course Schedule - Google Docs',
#        u'sync_transaction_version': u'506',
#        u'type': u'url',
#        u'url': u'https://docs.google.com/document/d/1KTwD2pMbL4YzH0DmGFtVroJGobge2y3CitQJdBC-CpU/edit#'},
#       {u'date_added': u'13124433797892610',
#        u'id': u'676',
#        u'name': u'Data Analytics Course - Google Docs',
#        u'sync_transaction_version': u'506',
#        u'type': u'url',
#        u'url': u'https://docs.google.com/document/d/1-YaxwOSKtCFIfzl9TNVHqMR-X65kFFmT_yJPZpXpTqQ/edit#'}],
#      u'date_added': u'13123922455068318',
#      u'date_modified': u'13124817240229167',
#      u'id': u'659',
#      u'name': u'FrontAnalytics',
#      u'sync_transaction_version': u'477',
#      u'type': u'folder'},
#     {u'date_added': u'13124345308515898',
#      u'id': u'669',
#      u'name': u'Hours',
#      u'sync_transaction_version': u'495',
#      u'type': u'url',
#      u'url': u'https://docs.google.com/spreadsheets/d/1lYm9U0InatMiUdsVV3--woP8OrH54L4USOQKPl2qfVc/edit#gid=0'}],
#    u'date_added': u'13099436592549436',
#    u'date_modified': u'13124403603230136',
#    u'id': u'1',
#    u'name': u'Bookmarks Bar',
#    u'sync_transaction_version': u'3',
#    u'type': u'folder'},
#   u'other': {u'children': [{u'children': [{u'date_added': u'13120587775886596',
#        u'id': u'607',
#        u'name': u'Incredible StartPage Settings',
#        u'sync_transaction_version': u'359',
#        u'type': u'url',
#        u'url': u'chrome-extension://ncdfeghkpohnalmpblddmnppfooljekh/options.html'}],
#      u'date_added': u'13120587775882155',
#      u'date_modified': u'13120587775886596',
#      u'id': u'606',
#      u'name': u'Extension Settings',
#      u'sync_transaction_version': u'358',
#      u'type': u'folder'}],
#    u'date_added': u'13099436592549450',
#    u'date_modified': u'13120587775883727',
#    u'id': u'2',
#    u'name': u'Other Bookmarks',
#    u'sync_transaction_version': u'3',
#    u'type': u'folder'},
#   u'sync_transaction_version': u'516',
#   u'synced': {u'children': [],
#    u'date_added': u'13099436592549450',
#    u'date_modified': u'0',
#    u'id': u'3',
#    u'name': u'Mobile Bookmarks',
#    u'sync_transaction_version': u'3',
#    u'type': u'folder'}},
#  u'version': 1}
